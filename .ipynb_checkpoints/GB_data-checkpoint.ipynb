# %%
import pandas as pd
from sqlalchemy import create_engine
import json

# %%
GBvideos_file = "GB/GBvideos.csv"
GB_videos = pd.read_csv(GBvideos_file)
GB_videos.head()
# Out:
#       video_id trending_date  \
# 0  Jw1Y-zhQURU      17.14.11
# 1  3s1rvMFUweQ      17.14.11
# 2  n1WpP7iowLc      17.14.11
# 3  PUTEiSjKwJU      17.14.11
# 4  rHwDegptbI4      17.14.11
#
#                                                title  \
# 0      John Lewis Christmas Ad 2017 - #MozTheMonster
# 1          Taylor Swift: …Ready for It? (Live) - SNL
# 2         Eminem - Walk On Water (Audio) ft. Beyoncé
# 3  Goals from Salford City vs Class of 92 and Fri...
# 4  Dashcam captures truck's near miss with child ...
#
#                 channel_title  category_id              publish_time  \
# 0                  John Lewis           26  2017-11-10T07:38:29.000Z
# 1         Saturday Night Live           24  2017-11-12T06:24:44.000Z
# 2                  EminemVEVO           10  2017-11-10T17:00:03.000Z
# 3  Salford City Football Club           17  2017-11-13T02:30:38.000Z
# 4            Cute Girl Videos           25  2017-11-13T01:45:13.000Z
#
# ...

# %%
GB_videos.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
GB_json_file = "GB/GB_category_id.json"
type(GB_json_file)
# Out:
# str

# %%
GB_json_df=pd.read_json(GB_json_file)
GB_json_df.head()
# Out:
#                                 kind  \
# 0  youtube#videoCategoryListResponse
# 1  youtube#videoCategoryListResponse
# 2  youtube#videoCategoryListResponse
# 3  youtube#videoCategoryListResponse
# 4  youtube#videoCategoryListResponse
#
#                                                 etag  \
# 0  "m2yskBQFythfE4irbTIeOgYYfBU/1v2mrzYSYG6onNLt2...
# 1  "m2yskBQFythfE4irbTIeOgYYfBU/1v2mrzYSYG6onNLt2...
# 2  "m2yskBQFythfE4irbTIeOgYYfBU/1v2mrzYSYG6onNLt2...
# 3  "m2yskBQFythfE4irbTIeOgYYfBU/1v2mrzYSYG6onNLt2...
# 4  "m2yskBQFythfE4irbTIeOgYYfBU/1v2mrzYSYG6onNLt2...
#
#                                                items
# 0  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 1  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 2  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 3  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 4  {'kind': 'youtube#videoCategory', 'etag': '"m2...

# %%
list_countries = ["GB/GB_category_id.json"]
category = []

# %%
for country in list_countries:
    json_data = json.load(open(country,'r'))
    for data in json_data['items']:
        category.append([data['id'],data['snippet']['title']])

category
# Out:
# [['1', 'Film & Animation'],
#  ['2', 'Autos & Vehicles'],
#  ['10', 'Music'],
#  ['15', 'Pets & Animals'],
#  ['17', 'Sports'],
#  ['18', 'Short Movies'],
#  ['19', 'Travel & Events'],
#  ['20', 'Gaming'],
#  ['21', 'Videoblogging'],
#  ['22', 'People & Blogs'],
#  ['23', 'Comedy'],
#  ['24', 'Entertainment'],
#  ['25', 'News & Politics'],
#  ['26', 'Howto & Style'],
#  ['27', 'Education'],
#  ['28', 'Science & Technology'],
#  ['30', 'Movies'],
#  ['31', 'Anime/Animation'],
#  ['32', 'Action/Adventure'],
#  ['33', 'Classics'],
#  ['34', 'Comedy'],
#  ['35', 'Documentary'],
#  ['36', 'Drama'],
#  ['37', 'Family'],
#  ['38', 'Foreign'],
#  ['39', 'Horror'],
#  ['40', 'Sci-Fi/Fantasy'],
#  ['41', 'Thriller'],
#  ['42', 'Shorts'],
#  ['43', 'Shows'],
#  ['44', 'Trailers']]

# %%
gb_cols = ['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
       'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
       'thumbnail_link', 'comments_disabled', 'ratings_disabled',
       'video_error_or_removed', 'description']
GB_df = GB_videos[gb_cols].copy()
GB_df.insert(1,'country','GB')
GB_df.head()
# Out:
#       video_id country trending_date  \
# 0  Jw1Y-zhQURU      GB      17.14.11
# 1  3s1rvMFUweQ      GB      17.14.11
# 2  n1WpP7iowLc      GB      17.14.11
# 3  PUTEiSjKwJU      GB      17.14.11
# 4  rHwDegptbI4      GB      17.14.11
#
#                                                title  \
# 0      John Lewis Christmas Ad 2017 - #MozTheMonster
# 1          Taylor Swift: …Ready for It? (Live) - SNL
# 2         Eminem - Walk On Water (Audio) ft. Beyoncé
# 3  Goals from Salford City vs Class of 92 and Fri...
# 4  Dashcam captures truck's near miss with child ...
#
#                 channel_title  category_id              publish_time  \
# 0                  John Lewis           26  2017-11-10T07:38:29.000Z
# 1         Saturday Night Live           24  2017-11-12T06:24:44.000Z
# 2                  EminemVEVO           10  2017-11-10T17:00:03.000Z
# 3  Salford City Football Club           17  2017-11-13T02:30:38.000Z
# ...

# %%
GB_category_map={1: 'Film & Animation', 2: 'Autos & Vehicles', 10: 'Music', 15: 'Pets & Animals', 17: 'Sports',
                 18: 'Short Movies', 19: 'Travel & Events', 20: 'Gaming', 21: 'Videoblogging',22: 'People & Blogs'
                 ,23: 'Comedy',24: 'Entertainment',25: 'News & Politics',26: 'Howto & Style',27:'Education',
                  28: 'Science & Technology',29: 'Nonprofits & Activism',30: 'Movies',31: 'Anime/Animation',
                  32: 'Action/Adventure',33: 'Classics',34: 'Comedy',35: 'Documentary',36: 'Drama',37: 'Family',
                 38: 'Foreign',39: 'Horror', 40: 'Sci-Fi/Fantasy',41: 'Thriller',42: 'Shorts',43: 'Shows',44: 'Trailers'}

GB_df['category_name']= GB_df['category_id'].map(GB_category_map)
GB_df.head()
# Out:
#       video_id country trending_date  \
# 0  Jw1Y-zhQURU      GB      17.14.11
# 1  3s1rvMFUweQ      GB      17.14.11
# 2  n1WpP7iowLc      GB      17.14.11
# 3  PUTEiSjKwJU      GB      17.14.11
# 4  rHwDegptbI4      GB      17.14.11
#
#                                                title  \
# 0      John Lewis Christmas Ad 2017 - #MozTheMonster
# 1          Taylor Swift: …Ready for It? (Live) - SNL
# 2         Eminem - Walk On Water (Audio) ft. Beyoncé
# 3  Goals from Salford City vs Class of 92 and Fri...
# 4  Dashcam captures truck's near miss with child ...
#
#                 channel_title  category_id              publish_time  \
# 0                  John Lewis           26  2017-11-10T07:38:29.000Z
# 1         Saturday Night Live           24  2017-11-12T06:24:44.000Z
# 2                  EminemVEVO           10  2017-11-10T17:00:03.000Z
# 3  Salford City Football Club           17  2017-11-13T02:30:38.000Z
# ...

# %%
top_10_trending_cols = ["video_id", "title", "views", "category_id", "country"]
top_10_videos = GB_df[top_10_trending_cols].copy()
top_10_videos.drop_duplicates("video_id", inplace=True)
top_10_videos.set_index("video_id", inplace=False)
top10 = top_10_videos.sort_values(by='views', ascending=False).head(10)

top10
# Out:
#           video_id                                              title  \
# 3587   TyHvyGVs42U          Luis Fonsi, Demi Lovato - Échame La Culpa
# 32412  zEf423kYfqk  Becky G, Natti Natasha - Sin Pijama (Official ...
# 28479  WtE011iVx1Q  Sebastián Yatra - Por Perro ft. Luis Figueroa,...
# 31702  Ck4xHocysLw           Ozuna - Única (Video Oficial) 🐻 A U R A
# 34463  7C2z4GqqS5E                BTS (방탄소년단) 'FAKE LOVE' Official MV
# 19664  VTzD0jNdrmo  Rkm & Ken-Y ❌ Natti Natasha - Tonta [Official ...
# 28458  i0p1bmr0EmE                            TWICE What is Love? M/V
# 3198   6ZfuNTqbHE8  Marvel Studios' Avengers: Infinity War Officia...
# 19593  xpVfcZ0ZcFM                                 Drake - God’s Plan
# 6      2Vv-BfVoq4g        Ed Sheeran - Perfect (Official Music Video)
#
#            views  category_id country
# 3587   143408235           10      GB
# 32412   88568646           10      GB
# 28479   47669287           10      GB
# 31702   42923278           10      GB
# ...

# %%
top_viewed_videos_cols = ["video_id", "title", "likes", "trending_date", "category_id", "country"]
top_viewed_videos = GB_df[top_viewed_videos_cols].copy()
top_viewed_videos.drop_duplicates("video_id", inplace=True)
top_viewed_videos.set_index("video_id", inplace=False)
most_views = top_viewed_videos.sort_values(by='likes', ascending=False).head(10)
most_views
# Out:
#           video_id                                              title  \
# 34463  7C2z4GqqS5E                BTS (방탄소년단) 'FAKE LOVE' Official MV
# 3587   TyHvyGVs42U          Luis Fonsi, Demi Lovato - Échame La Culpa
# 19593  xpVfcZ0ZcFM                                 Drake - God’s Plan
# 2199   kTlv5_Bs8aw  BTS (방탄소년단) 'MIC Drop (Steve Aoki Remix)' Offi...
# 21177  OK3GJ0WIQ8s                         j-hope 'Daydream (백일몽)' MV
# 32488  p8npDG2ulKQ  BTS (방탄소년단) LOVE YOURSELF 轉 Tear 'Singularity'...
# 3198   6ZfuNTqbHE8  Marvel Studios' Avengers: Infinity War Officia...
# 6      2Vv-BfVoq4g        Ed Sheeran - Perfect (Official Music Video)
# 28034  kX0vO4vlJuU  BTS (방탄소년단) 'Euphoria : Theme of LOVE YOURSELF...
# 36739  D_6QmL6rExk  BTS (방탄소년단) 'FAKE LOVE' Official MV (Extended ...
#
#          likes trending_date  category_id country
# 34463  3880074      18.19.05           10      GB
# 3587   2686169      17.01.12           10      GB
# ...

# %%
comments_cols = ["video_id", "title", "comment_count", "category_id","country"]
top_comments = GB_df[comments_cols].copy()
top_comments.drop_duplicates("video_id", inplace=True)
top_comments.set_index("video_id", inplace=False)
top_comments = top_comments.sort_values(by='comment_count', ascending=False).head(10)
top_comments
# Out:
#           video_id                                              title  \
# 9993   QwZT7T-TXT0                                          So Sorry.
# 34463  7C2z4GqqS5E                BTS (방탄소년단) 'FAKE LOVE' Official MV
# 4593   FlsCjmMhFmw  YouTube Rewind: The Shape of 2017 | #YouTubeRe...
# 16389  _5d-sQ7Fh5M                                LOGAN PAUL IS BACK!
# 2199   kTlv5_Bs8aw  BTS (방탄소년단) 'MIC Drop (Steve Aoki Remix)' Offi...
# 21177  OK3GJ0WIQ8s                         j-hope 'Daydream (백일몽)' MV
# 13992  oWjxSkJpxFU                         Suicide: Be Here Tomorrow.
# 32488  p8npDG2ulKQ  BTS (방탄소년단) LOVE YOURSELF 轉 Tear 'Singularity'...
# 3198   6ZfuNTqbHE8  Marvel Studios' Avengers: Infinity War Officia...
# 15642  qtTM2YV3bI8              Lucas Lucco e Pabllo Vittar - Paraíso
#
#        comment_count  category_id country
# 9993          733371           24      GB
# 34463         692311           10      GB
# 4593          462108           24      GB
# ...

# %%
category_cols = ["category_name","country"]
category_counts = GB_df[category_cols].copy()

GB_df.groupby(['category_name']).size()
GB_df.groupby(['category_name']).size().reset_index(name='number_of_videos')

#category_counts.merge(counts_cat, how='left', on='index')
# Out:
#             category_name  number_of_videos
# 0        Autos & Vehicles               144
# 1                  Comedy              1828
# 2               Education               457
# 3           Entertainment              9124
# 4        Film & Animation              2577
# 5                  Gaming              1788
# 6           Howto & Style              1928
# 7                   Music             13754
# 8         News & Politics              1225
# 9   Nonprofits & Activism                90
# 10         People & Blogs              2926
# 11         Pets & Animals               534
# 12   Science & Technology               518
# 13                  Shows                20
# 14                 Sports              1907
# 15        Travel & Events                96
